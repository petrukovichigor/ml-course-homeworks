# %% [markdown]
# <a href="https://colab.research.google.com/github/petrukovichigor/ml-course-homeworks/blob/main/hw01_setup_tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pow(2,3)
# Out:
# 8
